# %% [markdown]
# #### 导入数据

# %% [markdown]
# 创建kNN.py文件，并添加如下代码：

# %% [markdown]
# ```
# from numpy import *
# import operator
#
# def createDataSet():
#     group = array([[1.0,1.0],[1.0,1.0],[0,0]])
#     labels = ['A','A','B','B']
#     return group, labels
# ```

# %%
import kNN

# %%
group, labels = kNN.createDataSet()

# %%
group
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [0., 0.]])

# %%
labels
# Out:
# ['A', 'A', 'B', 'B']

# %%
kNN.classify0([0,0],group,labels,3)
# Out:
# 'A'
